# %% [markdown]
# <a href="https://colab.research.google.com/github/wtfashwin/Python-/blob/main/Data_Manipulation_%26_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a dictionary with the data from the image
data = {
    'Day': ['01-01-2024', '02-01-2024', '03-01-2024', '04-01-2024', '05-01-2024', '06-01-2024', '07-01-2024', '08-01-2024', '09-01-2024'],
    'Temperature': [32, 35, 23, 24, 29, 37, 38, 27, 22],
    'Windspeed': [6, 7, 2, 7, 4, 8, 7, 5, 1],
    'Event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny', 'Sunny', 'Rain', 'Snow']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file named 'sample_data.csv'
# index=False is used to prevent pandas from writing the DataFrame index to the CSV file
df.to_csv('sample_data.csv', index=False)

print("sample_data.csv file has been created successfully in your current directory.")
print("\nHere is the content of the file:")

# Read the created file and print its content to verify
with open('sample_data.csv', 'r') as f:
    print(f.read())
# Out:
# sample_data.csv file has been created successfully in your current directory.
#
# Here is the content of the file:
# Day,Temperature,Windspeed,Event
# 01-01-2024,32,6,Rain
# 02-01-2024,35,7,Sunny
# 03-01-2024,23,2,Snow
# 04-01-2024,24,7,Snow
# 05-01-2024,29,4,Rain
# 06-01-2024,37,8,Sunny
# 07-01-2024,38,7,Sunny
# 08-01-2024,27,5,Rain
# 09-01-2024,22,1,Snow

# %%
# Cannot concat dict
#only Series and DataFrame objs are valid

nr = {'Day':'10-01-2024',
      'Temperature':38,
      'Windspeed':8,
      'Event':'Sunny'
}

df1 = pd.DataFrame([nr])
df = pd.concat([df, df1], ignore_index=True)
#ignore_index=True if not given adds a new one
#hence we
print(df)
# Out:
#            Day  Temperature  Windspeed  Event  Temp
# 0   01-01-2024         32.0          6   Rain   NaN
# 1   02-01-2024         35.0          7  Sunny   NaN
# 2   03-01-2024         23.0          2   Snow   NaN
# 3   04-01-2024         24.0          7   Snow   NaN
# 4   05-01-2024         29.0          4   Rain   NaN
# 5   06-01-2024         37.0          8  Sunny   NaN
# 6   07-01-2024         38.0          7  Sunny   NaN
# 7   08-01-2024         27.0          5   Rain   NaN
# 8   09-01-2024         22.0          1   Snow   NaN
# 9   10-01-2024          NaN          8  Sunny  38.0
# 10  10-01-2024          NaN          8  Sunny  38.0
# 11  10-01-2024         38.0          8  Sunny   NaN
# 12  10-01-2024         38.0          8  Sunny   NaN

# %%
#for more than one record, we can use list
nr  = {'Day':['11-01-2024', '10-03-2025'],
       'Temperature':['37', '33'],
       'Windspeed':['9', '19'],
       'Event': ['Sunny', 'Rain']
       }

new_records_df = pd.DataFrame(nr)
df = pd.concat([df, new_records_df], ignore_index=True)
print(df)
# Out:
#            Day Temperature Windspeed  Event  Temp
# 0   01-01-2024        32.0         6   Rain   NaN
# 1   02-01-2024        35.0         7  Sunny   NaN
# 2   03-01-2024        23.0         2   Snow   NaN
# 3   04-01-2024        24.0         7   Snow   NaN
# 4   05-01-2024        29.0         4   Rain   NaN
# 5   06-01-2024        37.0         8  Sunny   NaN
# 6   07-01-2024        38.0         7  Sunny   NaN
# 7   08-01-2024        27.0         5   Rain   NaN
# 8   09-01-2024        22.0         1   Snow   NaN
# 9   10-01-2024         NaN         8  Sunny  38.0
# 10  10-01-2024         NaN         8  Sunny  38.0
# 11  10-01-2024        38.0         8  Sunny   NaN
# 12  10-01-2024        38.0         8  Sunny   NaN
# 13  11-01-2024          37         9  Sunny   NaN
# 14  10-03-2025          33        19   Rain   NaN

# %%
insert_at = 2
insert_att = 1
df_top = df.iloc[:insert_at]
df_bottom=df.iloc[insert_att:]

# %%
df = pd.concat([df_top, df1,df_bottom],ignore_index=True)
print(df)
# Out:
#            Day Temperature Windspeed  Event  Temp
# 0   01-01-2024        32.0         6   Rain   NaN
# 1   02-01-2024        35.0         7  Sunny   NaN
# 2   10-01-2024          38         8  Sunny   NaN
# 3   02-01-2024        35.0         7  Sunny   NaN
# 4   03-01-2024        23.0         2   Snow   NaN
# 5   04-01-2024        24.0         7   Snow   NaN
# 6   05-01-2024        29.0         4   Rain   NaN
# 7   06-01-2024        37.0         8  Sunny   NaN
# 8   07-01-2024        38.0         7  Sunny   NaN
# 9   08-01-2024        27.0         5   Rain   NaN
# 10  09-01-2024        22.0         1   Snow   NaN
# 11  10-01-2024         NaN         8  Sunny  38.0
# 12  10-01-2024         NaN         8  Sunny  38.0
# 13  10-01-2024        38.0         8  Sunny   NaN
# 14  10-01-2024        38.0         8  Sunny   NaN
# 15  11-01-2024          37         9  Sunny   NaN
# 16  10-03-2025          33        19   Rain   NaN

# %%
df = df.drop('Temp', axis=1)
display(df)
# Out:
#            Day Temperature Windspeed  Event
# 0   01-01-2024        32.0         6   Rain
# 1   02-01-2024        35.0         7  Sunny
# 2   10-01-2024          38         8  Sunny
# 3   02-01-2024        35.0         7  Sunny
# 4   03-01-2024        23.0         2   Snow
# 5   04-01-2024        24.0         7   Snow
# 6   05-01-2024        29.0         4   Rain
# 7   06-01-2024        37.0         8  Sunny
# 8   07-01-2024        38.0         7  Sunny
# 9   08-01-2024        27.0         5   Rain
# 10  09-01-2024        22.0         1   Snow
# 11  10-01-2024         NaN         8  Sunny
# 12  10-01-2024         NaN         8  Sunny
# 13  10-01-2024        38.0         8  Sunny
# 14  10-01-2024        38.0         8  Sunny
# 15  11-01-2024          37         9  Sunny
# 16  10-03-2025          33        19   Rain

# %%
df.drop(index=2, inplace=True)
print(df)
# Out:
#            Day Temperature Windspeed  Event
# 0   01-01-2024        32.0         6   Rain
# 1   02-01-2024        35.0         7  Sunny
# 3   02-01-2024        35.0         7  Sunny
# 4   03-01-2024        23.0         2   Snow
# 5   04-01-2024        24.0         7   Snow
# 6   05-01-2024        29.0         4   Rain
# 7   06-01-2024        37.0         8  Sunny
# 8   07-01-2024        38.0         7  Sunny
# 9   08-01-2024        27.0         5   Rain
# 10  09-01-2024        22.0         1   Snow
# 11  10-01-2024         NaN         8  Sunny
# 12  10-01-2024         NaN         8  Sunny
# 13  10-01-2024        38.0         8  Sunny
# 14  10-01-2024        38.0         8  Sunny
# 15  11-01-2024          37         9  Sunny
# 16  10-03-2025          33        19   Rain

# %%
print(df['Day'].dtype)
# Out:
# object

# %%
df['Day'] = pd.to_datetime(df['Day'])
print(df)
# Out:
#           Day Temperature Windspeed  Event
# 0  2024-01-01        32.0         6   Rain
# 1  2024-02-01        35.0         7  Sunny
# 3  2024-02-01        35.0         7  Sunny
# 4  2024-03-01        23.0         2   Snow
# 5  2024-04-01        24.0         7   Snow
# 6  2024-05-01        29.0         4   Rain
# 7  2024-06-01        37.0         8  Sunny
# 8  2024-07-01        38.0         7  Sunny
# 9  2024-08-01        27.0         5   Rain
# 10 2024-09-01        22.0         1   Snow
# 11 2024-10-01         NaN         8  Sunny
# 12 2024-10-01         NaN         8  Sunny
# 13 2024-10-01        38.0         8  Sunny
# 14 2024-10-01        38.0         8  Sunny
# 15 2024-11-01          37         9  Sunny
# 16 2025-10-03          33        19   Rain

# %%
df = df.drop([15, 16])
display(df)
# Out:
#           Day Temperature Windspeed  Event
# 0  2024-01-01        32.0         6   Rain
# 1  2024-02-01        35.0         7  Sunny
# 3  2024-02-01        35.0         7  Sunny
# 4  2024-03-01        23.0         2   Snow
# 5  2024-04-01        24.0         7   Snow
# 6  2024-05-01        29.0         4   Rain
# 7  2024-06-01        37.0         8  Sunny
# 8  2024-07-01        38.0         7  Sunny
# 9  2024-08-01        27.0         5   Rain
# 10 2024-09-01        22.0         1   Snow
# 13 2024-10-01        38.0         8  Sunny
# 14 2024-10-01        38.0         8  Sunny

# %%
df_sort = df.sort_values(by='Temperature')

# %% [markdown]
# ##Matplotlib
#
# used for visualization, diagrams, charts etc
#
# 1. Line Plot
# 2. Scatter Plot
# 3. Bar Chart
# 4. Histogram
# 5. PieChart
# 6. Error Chart

# %% [markdown]
# ####Line Chart

# %%
import matplotlib.pyplot as plt

#line plot
x = [1,6,3,8,4,6,7,8,9]
y = [2,9,4,5,1,7,8,9,2]

plt.plot(x,y)
plt.title('Line Chart')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('X')
plt.show()

# %%
import numpy as np
x = np.linspace(0,2,100)
plt.plot(x, x, label='linear')
plt.plot(x,x**2,label='Quadratic')
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %%
import numpy as np
x = np.linspace(0,2,100)
plt.plot(x, x, label='linear')
plt.plot(x,x**2,label='Quadratic')
plt.plot(x,x**3,label='Cubic')
plt.title('Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %% [markdown]
# ####Scatter Plot

# %%
import random
x = np.random.randn(150)
y = np.random.randn(150)
#x and y should be same
plt.scatter(x,y)
plt.title('Scatter Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# What are Outliers?
#
# Outliers are data points that are significantly different from other observations in a dataset. They lie an unusual distance from the rest of the data.
#
# Why are Outliers not Good?
#
# Outliers can:
#
# * Distort statistical measures like the mean and standard deviation.
# Affect the performance of machine learning models.
# * Lead to incorrect conclusions from data analysis.
# Represent errors in data collection or entry.

# %% [markdown]
# ####Bar Chart

# %%
categories = ['A', 'B', 'C', 'D', 'E']
val = [20, 40, 60, 80 , 100]
plt.bar(categories, val)
plt.title('Bar Chart')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
#Plot the bar horizontally -- use barh

categories = ['A', 'B', 'C', 'D', 'E']
val = [20, 40, 60, 80 , 100]
plt.barh(categories, val)
plt.title('Bar Chart')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
a = [10, 20, 13, 19, 21]
b = [9, 3, 22, 17, 27]

z = range(5)
plt.bar(z, a, color='y')
# plt.bar(z, b, color='g')
plt.bar(z,b,color='g',bottom=a)
#bottom A
plt.show()

# %% [markdown]
# #Data Analysis
#
# 1. df.head()
# 2. df.tail()
# 3. df.columns()
# 4. sorting, other manipulation : clean, sort, rename,type change -- preparation
# 5. data visualization- Trend, pattern, using matplotlib
# 6. post manipulation - optional

# %% [markdown]
# ####Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.rand(1000)
plt.hist(data, bins=30)
#data distribution | 30 == range | interval
#How many distributions of data wanted
plt.title('Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ####Pie Chart

# %%
label = ['Frogs', 'Dogs', 'Logs', 'Hogs']
size = [13, 26, 39, 19]
plt.pie(size, labels = label)

plt.title('Pie Chart')
plt.legend()

plt.show()

# %% [markdown]
# - **autopct** is a parameter in the matplotlib.pyplot.pie() function in Python. It's used to display the percentage values on the pie chart slices.
#     - What it does:
#
#          - It takes a string format or a function as input.
#
#          - It calculates the percentage for each slice of the pie chart.
#
#          - It then formats that percentage according to the specified format and places the text directly on the slice.
#
#
#
# - **startangle**
#  parameter controls the starting position of the first slice of the pie chart.
#
#     - What it does: It rotates the entire pie chart by a specified angle, measured in degrees. The rotation is counter-clockwise from the positive x-axis (which is the 3 o'clock position on a clock face).
#
#     - Default value: The default startangle is 0, which means the first slice starts at the 3 o'clock position and expands counter-clockwise.
#
# - **pctdistance**
#    is another parameter in the matplotlib.pyplot.pie() function, and it's specifically for controlling the placement of the percentage labels generated by autopct.
#
#      - What it does: It sets the radial distance of the percentage labels from the center of the pie chart. Like labeldistance, it is a fraction of the pie's radius.
#
#      - Default value: The default pctdistance is 0.6. This value places the percentage labels inside the pie, often closer to the center than the labels themselves.

# %%
label = ['Frogs', 'Dogs', 'Logs', 'Hogs']
size = [13, 26, 39, 19]
fig1, ax1 = plt.subplots()
ax1.pie(size,labels=label,autopct='%1.1f%%', startangle=90, labeldistance=1.1,pctdistance=1.3)
#pctdistance more
ax1.axis('equal')
plt.title('Pie Chart Values Outside')
plt.legend()
plt.show()

# %%
label = ['A', 'B', 'C', 'D', 'E']
size = [13, 26, 39, 19, 27]
fig1, ax1 = plt.subplots()
ax1.pie(size,labels=label,autopct='%1.1f%%', startangle=90, labeldistance=1.1,pctdistance=0.5)
ax1.axis('equal')
plt.title('Pie Chart')
plt.legend()
plt.show()

# %% [markdown]
# #### Error Plot
#
#    - Actual Value - we plot in error plot in chart, can contain mistakes
#    - machine value - precise value , machine predicted
#
# - **Residual value = Actual Value - Machine Value**

# %%
#import libraries
import matplotlib.pyplot as plt
import numpy as np

# Data Generation
# np.arange() creates an array of evenly spaced values within a given interval.
# It starts at 0.1, ends before 4, and has a step size of 0.5.
# This creates our x-axis data points.
x = np.arange(0.1, 4, 0.5)
# x = np.arange(start ,stop, step_size)
# Calculate the corresponding y-axis values using the exponential function.
# np.exp() applies the natural exponential function (e^x) to each element in the array `x`.
y = np.exp(-x)

# Create an array to represent the error for each y-value.
# The error is calculated as a linear function of x.
# This gives a varying error for each data point, increasing as x increases.
error = 0.1 + 0.2 * x

# --- Plotting ---
# plt.errorbar() is the function used to create a line plot with error bars.
# It takes the x and y data, and the error to be displayed.
# `yerr=error`: Specifies the vertical error for each data point from the `error` array.
# `fmt='-o'`: This is a format string.
#    '-' tells matplotlib to draw a line connecting the data points.
#    'o' tells matplotlib to use circular markers for each data point.
plt.errorbar(x, y, yerr=error, fmt='-o')
plt.title('Error Bar')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### Box Plot

# %%
# generate random values , then + 1 , then + 1 in every iterations
data = [np.random.randn(100), np.random.randn(100)+1,np.random.randn(100)+1]
plt.boxplot(data)
plt.title('Box Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# #### HeatMap
#
# - A heatmap is a graphical representation of data where the individual values contained in a matrix are represented as colors. It's an excellent way to visualize a 2D array of data and see patterns, correlations, and trends.
#
# - **matplotlib.pyplot.imshow(X, cmap=None, aspect='equal', **kwargs)**

# %%
data_mat = np.random.randn(10, 10)
plt.imshow(data_mat, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Heat Map')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
