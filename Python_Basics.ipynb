# %% [markdown]
# <a href="https://colab.research.google.com/github/wtfashwin/Python-/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python : High level , object oriented , Dynamically Typed and interpreted programing langauge.

# %%
Low level : 0, 1
# 1. machine language
# 2.  Assembly language

# %%
print('hello world')

# %%
#High level language
1. Procedural oriented language
2. Object oriented language

# %%
string val = 'string'

# %%
val = 'String'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# 1. simple and easy to learn
# 2. Freeware and open source
# 3. Platform Independent

# %% [markdown]
# ## Keywords

# %%
import keyword

# %%
print(keyword.kwlist)
len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
word ='AAB'
print(keyword.iskeyword(word))
# Out:
# False

# %% [markdown]
# ## Variable

# %%
False

# %%
A = 50
# A is a variable which store the address of value 50

# %%
B = 50

# %%
Val = 235

# %%
print(Val)
# Out:
# 235

# %%
Name = 'Alice'
age = 23
website = 'www.google.com'

# %%
print(website)
# Out:
# www.google.com

# %%
# Python is case sensitive language

# %% [markdown]
# ## identifiers

# %% [markdown]
# ######Rules of identifiers
# 1. can include letter : A - Z, a-z
# 2. can include any digit :  0-9
# 3. can include Underscore : '_'
# 4. you can start with Underscore
# 5. Can be of any lenght
# 6. Python is case sensitive
# 7. NaMe

# %% [markdown]
# ##
# 1. You cannot use special character :  !,%,$,@
# 2. You cannot use python keywords
# 3. cannot conatain spaces:  First name
# 4. cannot start with a digit

# %%
First name = 'Alice'
print(First name)
# Out:
#   File "/tmp/ipython-input-18-4209071226.py", line 1
#     First name = 'Alice'
#           ^
# SyntaxError: invalid syntax

# %%
First_name = 'Tim'
Last_name = 'XYZ'

# %%
print(First_name)
print(Last_name)
# Out:
# Tim
# XYZ

# %% [markdown]
# ## Commenting
# * Give you extra information of code

# %%
# single line comment
# muliple line comment

# %%
Language = 'Python'  #This is my languege

# %%
print(Language)
# Out:
# Python

# %%
Language = 'Python'
""" Python is a programing language,
it is easy to understand
it is dynamically typed
"""
Name = 'ABC'

# %%
print(Language)
print(Name)
# Out:
# Python
# ABC

# %% [markdown]
# ## Data Type

# %% [markdown]
# ![Python-Data-Types-Overview.webp](data:image/webp;base64,...)

# %%
Integers : integers numbers
int --- > 10, 12,40 ,50,100

# %%
Float --> floating point numbers (decimal)
float --> 2.5, 1.5,9.0

# %%
Complex --> Complex numbers
2+3j --> real + imaginary
complex

# %%
boolean --> True , False
bool

# %%
Set --> unordered colection of unique items
set {}

# %%
dictionary --> collection of key : value
dict

# %%
string = 'Hello'
str

# %%
List --> ordered collection of element
example --[1,2,3,'abb',3.2]--> Mutable
list

# %%
Tuple --> ordered collection of element
example --> (1,2,3,'abb',3.2,True) --> Immutable
tuple
